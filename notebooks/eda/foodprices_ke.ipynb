# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv('C:\\Users\\wambu\\OneDrive\\Desktop\\Capstone project\\bei-smart\\data\\cleaned\\wfp_with_rainfall.csv')

# %%
df.shape
# Out:
# (27316, 18)
