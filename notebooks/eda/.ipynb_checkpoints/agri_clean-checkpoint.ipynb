# %%
import pandas as pd

# Load ERA5 data
era5 = pd.read_excel(r'C:\Users\matew\OneDrive\Documents\capstone\bei-smart\data\raw\era5-x0.25_timeseries_pr_timeseries_monthly_1950-2025_mean_historical_era5_x0.25_mean.xlsx')

# Pivot from wide to long
era5_long = era5.melt(
    id_vars=['code', 'name'],
    var_name='year_month',
    value_name='rainfall_mm'
)

# Parse year_month to datetime
era5_long['date'] = pd.to_datetime(era5_long['year_month'], format='%Y-%m')

# Rename county name column to match WFP
era5_long = era5_long.rename(columns={'name': 'county'})

# Save
era5_long.to_csv('era5_rainfall_long.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
wfp = pd.read_csv('../../data/raw/wfp_food_prices_ken.csv')
era5 = pd.read_csv('../../data/raw/era5_rainfall_long.csv')

# Quick inspection
print('WFP shape:', wfp.shape)
print('ERA5 shape:', era5.shape)
print('\nWFP columns:', wfp.columns.tolist())
print('\nWFP head:')
wfp.head()
# Out:
# WFP shape: (27384, 16)
# ERA5 shape: (42864, 5)
#
# WFP columns: ['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude', 'longitude', 'category', 'commodity', 'commodity_id', 'unit', 'priceflag', 'pricetype', 'currency', 'price', 'usdprice']
#
# WFP head:
#          date   admin1   admin2   market  market_id  latitude  longitude  \
# 0  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 1  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 2  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 3  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 4  2006-01-15  Eastern    Kitui    Kitui        187     -1.37      38.02
#
#              category      commodity  commodity_id   unit priceflag  \
# 0  cereals and tubers          Maize            51     KG    actual
# 1  cereals and tubers  Maize (white)            67  90 KG    actual
# ...

# %%
# Parse dates
wfp['date'] = pd.to_datetime(wfp['date'])
era5['date'] = pd.to_datetime(era5['date'])

# Check nulls
print('WFP nulls:')
print(wfp.isnull().sum())
print('\nWFP date range:', wfp['date'].min(), 'to', wfp['date'].max())
print('WFP unique commodities:', wfp['commodity'].nunique())
print('WFP unique markets:', wfp['market'].nunique())
print('WFP unique regions (admin1):', wfp['admin1'].nunique())
print('\nadmin1 values:', wfp['admin1'].unique())
# Out:
# WFP nulls:
# date             0
# admin1          68
# admin2          68
# market           0
# market_id        0
# latitude        68
# longitude       68
# category         0
# commodity        0
# commodity_id     0
# unit             0
# priceflag        0
# pricetype        0
# currency         0
# price            0
# usdprice         0
# dtype: int64
#
# WFP date range: 2006-01-15 00:00:00 to 2026-08-15 00:00:00
# WFP unique commodities: 51
# WFP unique markets: 226
# WFP unique regions (admin1): 7
#
# admin1 values: <ArrowStringArray>
# [        'Coast',       'Eastern',       'Nairobi', 'North Eastern',
#         'Nyanza',   'Rift Valley',             nan,       'Central']
# Length: 8, dtype: str

# %%
# Drop rows with missing admin1
wfp = wfp.dropna(subset=['admin1'])
print('WFP shape after dropping nulls:', wfp.shape)

# Check ERA5 county names
print('\nERA5 unique counties:', era5['county'].nunique())
print(era5['county'].unique()[:20])
# Out:
# WFP shape after dropping nulls: (27316, 16)
#
# ERA5 unique counties: 47
# <ArrowStringArray>
# ['Uasin Gishu',       'Kisii',       'Bomet',     'Nyamira',       'Busia',
#      'Bungoma',  'Tana River',    'Kakamega',        'Meru',     'Mombasa',
#  'Trans Nzoia',     'Kericho',     'Nairobi',       'Wajir',      'Vihiga',
#        'Narok',        'Embu',      'Kilifi',    'Murang'a',      'Kiambu']
# Length: 20, dtype: str

# %%
# Map WFP admin1 regions to ERA5 counties
region_to_counties = {
    'Coast':          ['Mombasa', 'Kilifi', 'Kwale', 'Tana River', 'Lamu', 'Taita-Taveta'],
    'Eastern':        ['Kitui', 'Machakos', 'Makueni', 'Embu', 'Meru', 'Tharaka-Nithi', 'Isiolo', 'Marsabit'],
    'Nairobi':        ['Nairobi'],
    'North Eastern':  ['Garissa', 'Wajir', 'Mandera'],
    'Nyanza':         ['Kisumu', 'Siaya', 'Homa Bay', 'Migori', 'Kisii', 'Nyamira'],
    'Rift Valley':    ['Nakuru', 'Uasin Gishu', 'Trans Nzoia', 'Kericho', 'Bomet', 'Nandi',
                       'Elgeyo-Marakwet', 'Samburu', 'Turkana', 'West Pokot', 'Baringo',
                       'Laikipia', 'Narok', 'Kajiado'],
    'Central':        ['Kiambu', 'Murang\'a', 'Kirinyaga', 'Nyeri', 'Nyandarua']
}

# Invert mapping — county to region
county_to_region = {}
for region, counties in region_to_counties.items():
    for county in counties:
        county_to_region[county] = region

# Add region column to ERA5
era5['admin1'] = era5['county'].map(county_to_region)

# Check mapping worked
print('ERA5 unmapped counties:', era5[era5['admin1'].isna()]['county'].unique())
print('\nERA5 with region sample:')
era5[['county', 'admin1', 'date', 'rainfall_mm']].head(10)
# Out:
# ERA5 unmapped counties: <ArrowStringArray>
# ['Busia', 'Bungoma', 'Kakamega', 'Vihiga', 'Taita Taveta']
# Length: 5, dtype: str
#
# ERA5 with region sample:
#         county       admin1       date  rainfall_mm
# 0  Uasin Gishu  Rift Valley 1950-01-01        72.31
# 1        Kisii       Nyanza 1950-01-01       282.98
# 2        Bomet  Rift Valley 1950-01-01       249.95
# 3      Nyamira       Nyanza 1950-01-01       253.24
# 4        Busia          NaN 1950-01-01       175.51
# 5      Bungoma          NaN 1950-01-01       156.47
# 6   Tana River        Coast 1950-01-01        22.38
# 7     Kakamega          NaN 1950-01-01       113.54
# 8         Meru      Eastern 1950-01-01        99.09
# 9      Mombasa        Coast 1950-01-01        31.52

# %%
# Fix unmapped counties
extra_mappings = {
    'Busia':        'Nyanza',   # WFP groups Western Kenya under Nyanza
    'Bungoma':      'Nyanza',
    'Kakamega':     'Nyanza',
    'Vihiga':       'Nyanza',
    'Taita Taveta': 'Coast'     # spacing fix
}

county_to_region.update(extra_mappings)
era5['admin1'] = era5['county'].map(county_to_region)

# Verify no more nulls
print('Remaining unmapped:', era5[era5['admin1'].isna()]['county'].unique())
print('All mapped:', era5['admin1'].isna().sum() == 0)
# Out:
# Remaining unmapped: <ArrowStringArray>
# []
# Length: 0, dtype: str
# All mapped: True

# %%
# Normalize WFP date to first of month to match ERA5
wfp['date_month'] = wfp['date'].dt.to_period('M').dt.to_timestamp()

# Aggregate ERA5 rainfall by region + month (average across counties in region)
era5_regional = era5.groupby(['admin1', 'date'])['rainfall_mm'].mean().reset_index()
era5_regional.rename(columns={'date': 'date_month'}, inplace=True)

# Merge
wfp_merged = wfp.merge(era5_regional, on=['admin1', 'date_month'], how='left')

print('Merged shape:', wfp_merged.shape)
print('Rainfall nulls after merge:', wfp_merged['rainfall_mm'].isna().sum())
wfp_merged[['date', 'admin1', 'market', 'commodity', 'price', 'rainfall_mm']].head(10)
# Out:
# Merged shape: (27316, 18)
# Rainfall nulls after merge: 1487
#         date   admin1    market         commodity    price  rainfall_mm
# 0 2006-01-15    Coast   Mombasa             Maize    16.13    17.813333
# 1 2006-01-15    Coast   Mombasa     Maize (white)  1480.00    17.813333
# 2 2006-01-15    Coast   Mombasa             Beans    33.63    17.813333
# 3 2006-01-15    Coast   Mombasa       Beans (dry)  3246.00    17.813333
# 4 2006-01-15  Eastern     Kitui     Maize (white)    17.00    44.527500
# 5 2006-01-15  Eastern     Kitui  Potatoes (Irish)  1249.99    44.527500
# 6 2006-01-15  Eastern     Kitui           Sorghum  1800.00    44.527500
# 7 2006-01-15  Eastern  Marsabit     Maize (white)    21.00    44.527500
# 8 2006-01-15  Nairobi   Nairobi             Bread    26.00    17.970000
# 9 2006-01-15  Nairobi   Nairobi             Maize    15.48    17.970000

# %%
# Save merged dataset
wfp_merged.to_csv('../../data/cleaned/wfp_with_rainfall.csv', index=False)
print('Saved! Shape:', wfp_merged.shape)
print('Columns:', wfp_merged.columns.tolist())
# Out:
# Saved! Shape: (27316, 18)
# Columns: ['date', 'admin1', 'admin2', 'market', 'market_id', 'latitude', 'longitude', 'category', 'commodity', 'commodity_id', 'unit', 'priceflag', 'pricetype', 'currency', 'price', 'usdprice', 'date_month', 'rainfall_mm']

# %%
import requests
import pandas as pd
import numpy as np

region_coords = {
    'Rift Valley':   {'lat': 0.52,  'lon': 35.87},
    'North Eastern': {'lat': 1.50,  'lon': 40.00},
    'Eastern':       {'lat': -0.50, 'lon': 38.50},
    'Coast':         {'lat': -3.50, 'lon': 39.50},
    'Nyanza':        {'lat': -0.50, 'lon': 34.50},
    'Nairobi':       {'lat': -1.29, 'lon': 36.82},
    'Central':       {'lat': -0.50, 'lon': 37.00}
}

def get_nasa_rainfall(lat, lon, start='2025', end='2025'):
    url = "https://power.larc.nasa.gov/api/temporal/monthly/point"
    params = {
        "parameters": "PRECTOTCORR",
        "community": "AG",
        "longitude": lon,
        "latitude": lat,
        "start": start,
        "end": end,
        "format": "JSON"
    }
    r = requests.get(url, params=params, timeout=30)
    return r.json()['properties']['parameter']['PRECTOTCORR']

# Fetch all regions
nasa_rainfall = {}
for region, coords in region_coords.items():
    print(f'Fetching {region}...')
    nasa_rainfall[region] = get_nasa_rainfall(coords['lat'], coords['lon'])

# Build month lookup (skip 13th key which is annual average)
nasa_monthly = {}
for region, monthly in nasa_rainfall.items():
    nasa_monthly[region] = {int(k[-2:]): v for k, v in monthly.items() if int(k[-2:]) <= 12}

# Fill nulls
def fill_with_nasa(row):
    if pd.isna(row['rainfall_mm']):
        return nasa_monthly.get(row['admin1'], {}).get(row['date'].month, np.nan)
    return row['rainfall_mm']

df['rainfall_mm'] = df.apply(fill_with_nasa, axis=1)
print('Remaining nulls:', df['rainfall_mm'].isna().sum())
# Out:
# Fetching Rift Valley...
# Fetching North Eastern...
# Fetching Eastern...
# Fetching Coast...
# Fetching Nyanza...
# Fetching Nairobi...
# Fetching Central...
# Remaining nulls: 0

# %%
df = pd.read_csv('../../data/cleaned/wfp_final_clean.csv', parse_dates=['date', 'date_month'])
print('Nulls:', df['rainfall_mm'].isna().sum())
print('Shape:', df.shape)
# Out:
# Nulls: 0
# Shape: (27316, 18)

# %%
df.to_csv('../../data/cleaned/wfp_final_clean.csv', index=False)
print('Saved:', df.shape)
# Out:
# Saved: (27316, 18)

# %%
#now eda
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# Settings
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12, 5)
sns.set_style('whitegrid')

# Load data
df = pd.read_csv('../../data/cleaned/wfp_final_clean.csv', parse_dates=['date', 'date_month'])
df.shape
# Out:
# (27316, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27316 entries, 0 to 27315
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          27316 non-null  datetime64[us]
#  1   admin1        27316 non-null  str
#  2   admin2        27316 non-null  str
#  3   market        27316 non-null  str
#  4   market_id     27316 non-null  int64
#  5   latitude      27316 non-null  float64
#  6   longitude     27316 non-null  float64
#  7   category      27316 non-null  str
#  8   commodity     27316 non-null  str
#  9   commodity_id  27316 non-null  int64
#  10  unit          27316 non-null  str
#  11  priceflag     27316 non-null  str
#  12  pricetype     27316 non-null  str
#  13  currency      27316 non-null  str
#  14  price         27316 non-null  float64
#  15  usdprice      27316 non-null  float64
#  16  date_month    27316 non-null  datetime64[us]
#  17  rainfall_mm   27316 non-null  float64
# ...

# %%
# Check where rainfall nulls come from
print('Rainfall null count:', df['rainfall_mm'].isna().sum())
print('Null % of total:', round(df['rainfall_mm'].isna().sum() / len(df) * 100, 2), '%')
print('\nNulls by region:')
print(df[df['rainfall_mm'].isna()]['admin1'].value_counts())
print('\nNulls by date range:')
null_dates = df[df['rainfall_mm'].isna()]['date']
print('From:', null_dates.min().date(), 'To:', null_dates.max().date())
# Out:
# Rainfall null count: 0
# Null % of total: 0.0 %
#
# Nulls by region:
# Series([], Name: count, dtype: int64)
#
# Nulls by date range:
# From: NaT To: NaT

# %%
# Basic stats
print('Date range:', df['date'].min().date(), 'to', df['date'].max().date())
print('Regions:', df['admin1'].unique())
print('Top 10 commodities:\n', df['commodity'].value_counts().head(10))
print('\nCategories:\n', df['category'].value_counts())
print('\nPrice stats:\n', df['price'].describe())
# Out:
# Date range: 2006-01-15 to 2026-08-15
# Regions: <ArrowStringArray>
# [        'Coast',       'Eastern',       'Nairobi', 'North Eastern',
#         'Nyanza',   'Rift Valley',       'Central']
# Length: 7, dtype: str
# Top 10 commodities:
#  commodity
# Beans (dry)         1806
# Maize (white)       1633
# Maize               1518
# Sugar               1418
# Wheat flour         1373
# Beans               1327
# Salt                1287
# Potatoes (Irish)    1275
# Sorghum             1012
# Rice (aromatic)      969
# Name: count, dtype: int64
#
# Categories:
#  category
# cereals and tubers       11951
# pulses and nuts           4851
# vegetables and fruits     3182
# miscellaneous food        2705
# oil and fats              1724
# milk and dairy            1629
# meat, fish and eggs       1075
# non-food                   199
# Name: count, dtype: int64
#
# Price stats:
#  count    27316.000000
# mean      1317.337703
# std       2593.837126
# min          5.000000
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Price distribution (log scale)
axes[0,0].hist(np.log1p(df['price']), bins=50, color='steelblue', edgecolor='white')
axes[0,0].set_title('Price Distribution (log scale)')
axes[0,0].set_xlabel('log(price)')

# 2. Records per region
df['admin1'].value_counts().plot(kind='bar', ax=axes[0,1], color='steelblue')
axes[0,1].set_title('Records per Region')
axes[0,1].set_xlabel('')
axes[0,1].tick_params(axis='x', rotation=45)

# 3. Records per category
df['category'].value_counts().plot(kind='bar', ax=axes[1,0], color='coral')
axes[1,0].set_title('Records per Category')
axes[1,0].tick_params(axis='x', rotation=45)

# 4. Rainfall distribution
axes[1,1].hist(df['rainfall_mm'].dropna(), bins=50, color='teal', edgecolor='white')
axes[1,1].set_title('Monthly Rainfall Distribution (mm)')
axes[1,1].set_xlabel('Rainfall (mm)')

plt.tight_layout()
plt.savefig('../../data/exports/eda_overview.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Focus commodity: Maize (most records, staple food)
maize = df[df['commodity'] == 'Maize'].copy()

monthly_maize = maize.groupby('date_month')['price'].mean().reset_index()

plt.figure(figsize=(14, 5))
plt.plot(monthly_maize['date_month'], monthly_maize['price'], color='steelblue', linewidth=1.5)
plt.title('Average Maize Price in Kenya (2006–2026)')
plt.xlabel('Date')
plt.ylabel('Price (KES/KG)')
plt.tight_layout()
plt.savefig('../../data/exports/maize_price_trend.png', dpi=150, bbox_inches='tight')
plt.show()

print('Maize records:', len(maize))
# Out:
# Maize records: 1518

# %%
# 6. Seasonal price patterns — average price by month across all years
monthly_avg = df.groupby(df['date'].dt.month)['price'].mean()
plt.figure(figsize=(10,4))
monthly_avg.plot(kind='bar', color='steelblue')
plt.title('Average Food Price by Month (Seasonal Pattern)')
plt.xlabel('Month')
plt.ylabel('Price (KES)')
plt.xticks(range(12), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], rotation=45)
plt.tight_layout()
plt.show()

# %%
# 7. Rainfall vs price correlation scatter
plt.figure(figsize=(8,5))
plt.scatter(df['rainfall_mm'], df['price'], alpha=0.1, color='teal')
plt.title('Rainfall vs Food Price')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Price (KES)')
plt.tight_layout()
plt.show()
print('Correlation:', df[['rainfall_mm','price']].corr().iloc[0,1].round(3))
# Out:
# Correlation: 0.049

# %%
# 8. Top 10 most expensive commodities (median price)
top_commodities = df.groupby('commodity')['price'].median().sort_values(ascending=False).head(10)
top_commodities.plot(kind='barh', figsize=(10,5), color='coral')
plt.title('Top 10 Commodities by Median Price')
plt.xlabel('Median Price (KES)')
plt.tight_layout()
plt.show()

# %%
# 9. Price volatility by region (std deviation)
volatility = df.groupby('admin1')['price'].std().sort_values(ascending=False)
volatility.plot(kind='bar', figsize=(10,4), color='steelblue')
plt.title('Price Volatility by Region (Std Deviation)')
plt.xlabel('Region')
plt.ylabel('Std Dev of Price (KES)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 10. Heatmap — average maize price by region and year
maize_pivot = df[df['commodity']=='Maize'].copy()
maize_pivot['year'] = maize_pivot['date'].dt.year
pivot = maize_pivot.groupby(['admin1','year'])['price'].mean().unstack()
plt.figure(figsize=(14,5))
sns.heatmap(pivot, cmap='YlOrRd', annot=False, linewidths=0.5)
plt.title('Average Maize Price by Region and Year')
plt.tight_layout()
plt.show()
